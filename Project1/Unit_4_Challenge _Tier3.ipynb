# %% [markdown]
# # Springboard Data Science Career Track Unit 4 Challenge - Tier 3 Complete
#
# ## Objectives
# Hey! Great job getting through those challenging DataCamp courses. You're learning a lot in a short span of time.
#
# In this notebook, you're going to apply the skills you've been learning, bridging the gap between the controlled environment of DataCamp and the *slightly* messier work that data scientists do with actual datasets!
#
# Here’s the mystery we’re going to solve: ***which boroughs of London have seen the greatest increase in housing prices, on average, over the last two decades?***
#
#
# A borough is just a fancy word for district. You may be familiar with the five boroughs of New York… well, there are 32 boroughs within Greater London [(here's some info for the curious)](https://en.wikipedia.org/wiki/London_boroughs). Some of them are more desirable areas to live in, and the data will reflect that with a greater rise in housing prices.
#
# ***This is the Tier 3 notebook, which means it's not filled in at all: we'll just give you the skeleton of a project, the brief and the data. It's up to you to play around with it and see what you can find out! Good luck! If you struggle, feel free to look at easier tiers for help; but try to dip in and out of them, as the more independent work you do, the better it is for your learning!***
#
# This challenge will make use of only what you learned in the following DataCamp courses:
# - Prework courses (Introduction to Python for Data Science, Intermediate Python for Data Science)
# - Data Types for Data Science
# - Python Data Science Toolbox (Part One)
# - pandas Foundations
# - Manipulating DataFrames with pandas
# - Merging DataFrames with pandas
#
# Of the tools, techniques and concepts in the above DataCamp courses, this challenge should require the application of the following:
# - **pandas**
#     - **data ingestion and inspection** (pandas Foundations, Module One)
#     - **exploratory data analysis** (pandas Foundations, Module Two)
#     - **tidying and cleaning** (Manipulating DataFrames with pandas, Module Three)
#     - **transforming DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **subsetting DataFrames with lists** (Manipulating DataFrames with pandas, Module One)
#     - **filtering DataFrames** (Manipulating DataFrames with pandas, Module One)
#     - **grouping data** (Manipulating DataFrames with pandas, Module Four)
#     - **melting data** (Manipulating DataFrames with pandas, Module Three)
#     - **advanced indexing** (Manipulating DataFrames with pandas, Module Four)
# - **matplotlib** (Intermediate Python for Data Science, Module One)
# - **fundamental data types** (Data Types for Data Science, Module One)
# - **dictionaries** (Intermediate Python for Data Science, Module Two)
# - **handling dates and times** (Data Types for Data Science, Module Four)
# - **function definition** (Python Data Science Toolbox - Part One, Module One)
# - **default arguments, variable length, and scope** (Python Data Science Toolbox - Part One, Module Two)
# - **lambda functions and error handling** (Python Data Science Toolbox - Part One, Module Four)

# %% [markdown]
# ## The Data Science Pipeline
#
# This is Tier Three, so we'll get you started. But after that, it's all in your hands! When you feel done with your investigations, look back over what you've accomplished, and prepare a quick presentation of your findings for the next mentor meeting.
#
# Data Science is magical. In this case study, you'll get to apply some complex machine learning algorithms. But as  [David Spiegelhalter](https://www.youtube.com/watch?v=oUs1uvsz0Ok) reminds us, there is no substitute for simply **taking a really, really good look at the data.** Sometimes, this is all we need to answer our question.
#
# Data Science projects generally adhere to the four stages of Data Science Pipeline:
# 1. Sourcing and loading
# 2. Cleaning, transforming, and visualizing
# 3. Modeling
# 4. Evaluating and concluding

# %% [markdown]
# ### 1. Sourcing and Loading
#
# Any Data Science project kicks off by importing  ***pandas***. The documentation of this wonderful library can be found [here](https://pandas.pydata.org/). As you've seen, pandas is conveniently connected to the [Numpy](http://www.numpy.org/) and [Matplotlib](https://matplotlib.org/) libraries.
#
# ***Hint:*** This part of the data science pipeline will test those skills you acquired in the pandas Foundations course, Module One.

# %% [markdown]
# #### 1.1. Importing Libraries

# %%
# Let's import the pandas, numpy libraries as pd, and np respectively. 
import numpy as np
import pandas as pd

# Load the pyplot collection of functions from matplotlib, as plt 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import itertools

# %% [markdown]
# #### 1.2.  Loading the data
# Your data comes from the [London Datastore](https://data.london.gov.uk/): a free, open-source data-sharing portal for London-oriented datasets.

# %%
# First, make a variable called url_LondonHousePrices, and assign it the following link, enclosed in quotation-marks as a string:
# https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls

url_LondonHousePrices = "https://data.london.gov.uk/download/uk-house-price-index/70ac0766-8902-4eb5-aab5-01951aaed773/UK%20House%20price%20index.xls"

# The dataset we're interested in contains the Average prices of the houses, and is actually on a particular sheet of the Excel file. 
# As a result, we need to specify the sheet name in the read_excel() method.
# Put this data into a variable called properties.  
properties = pd.read_excel(url_LondonHousePrices, sheet_name='Average price', index_col= None)

# %% [markdown]
# ### 2. Cleaning, transforming, and visualizing
# This second stage is arguably the most important part of any Data Science project. The first thing to do is take a proper look at the data. Cleaning forms the majority of this stage, and can be done both before or after Transformation.
#
# The end goal of data cleaning is to have tidy data. When data is tidy:
#
# 1. Each variable has a column.
# 2. Each observation forms a row.
#
# Keep the end goal in mind as you move through this process, every step will take you closer.
#
#
#
# ***Hint:*** This part of the data science pipeline should test those skills you acquired in:
# - Intermediate Python for data science, all modules.
# - pandas Foundations, all modules.
# - Manipulating DataFrames with pandas, all modules.
# - Data Types for Data Science, Module Four.
# - Python Data Science Toolbox - Part One, all modules

# %% [markdown]
# **2.1. Exploring your data**
#
# Think about your pandas functions for checking out a dataframe.

# %%
properties.head()
# Out:
#   Unnamed: 0 City of London Barking & Dagenham     Barnet     Bexley  \
# 0        NaT      E09000001          E09000002  E09000003  E09000004
# 1 1995-01-01          91449            50460.2    93284.5    64958.1
# 2 1995-02-01        82202.8            51085.8    93190.2    64787.9
# 3 1995-03-01        79120.7              51269    92247.5    64367.5
# 4 1995-04-01        77101.2            53133.5    90762.9    64277.7
#
#        Brent    Bromley     Camden    Croydon     Ealing  ... NORTH WEST  \
# 0  E09000005  E09000006  E09000007  E09000008  E09000009  ...  E12000002
# 1    71306.6    81671.5     120933    69158.2    79885.9  ...    43958.5
# 2    72022.3    81657.6     119509    68951.1    80897.1  ...    43925.4
# 3    72015.8    81449.3     120282    68712.4    81379.9  ...    44434.9
# 4    72965.6    81124.4     120098      68610    82188.9  ...    44267.8
#
#   YORKS & THE HUMBER EAST MIDLANDS WEST MIDLANDS EAST OF ENGLAND     LONDON  \
# ...

# %%
len(properties.columns)
# Out:
# 49

# %%
properties.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 306 entries, 0 to 305
# Data columns (total 49 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Unnamed: 0            305 non-null    datetime64[ns]
#  1   City of London        306 non-null    object
#  2   Barking & Dagenham    306 non-null    object
#  3   Barnet                306 non-null    object
#  4   Bexley                306 non-null    object
#  5   Brent                 306 non-null    object
#  6   Bromley               306 non-null    object
#  7   Camden                306 non-null    object
#  8   Croydon               306 non-null    object
#  9   Ealing                306 non-null    object
#  10  Enfield               306 non-null    object
#  11  Greenwich             306 non-null    object
#  12  Hackney               306 non-null    object
#  13  Hammersmith & Fulham  306 non-null    object
# ...

# %% [markdown]
# **2.2. Cleaning the data**
#
# You might find you need to transpose your dataframe, check out what its row indexes are, and reset the index. You  also might find you need to assign the values of the first row to your column headings  . (Hint: recall the .columns feature of DataFrames, as well as the iloc[] method).
#
# Don't be afraid to use StackOverflow for help  with this.

# %%
properties_t = properties.transpose()
properties_t.head()
# Out:
#                           0                    1                    2    \
# Unnamed: 0                NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# City of London      E09000001                91449              82202.8
# Barking & Dagenham  E09000002              50460.2              51085.8
# Barnet              E09000003              93284.5              93190.2
# Bexley              E09000004              64958.1              64787.9
#
#                                     3                    4    \
# Unnamed: 0          1995-03-01 00:00:00  1995-04-01 00:00:00
# City of London                  79120.7              77101.2
# Barking & Dagenham                51269              53133.5
# Barnet                          92247.5              90762.9
# Bexley                          64367.5              64277.7
#
#                                     5                    6    \
# Unnamed: 0          1995-05-01 00:00:00  1995-06-01 00:00:00
# ...

# %%
# Checking the index of the transposed DataFrame
properties_t.index
# Out:
# Index(['Unnamed: 0', 'City of London', 'Barking & Dagenham', 'Barnet',
#        'Bexley', 'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey', 'Harrow',
#        'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth', 'Lewisham',
#        'Merton', 'Newham', 'Redbridge', 'Richmond upon Thames', 'Southwark',
#        'Sutton', 'Tower Hamlets', 'Waltham Forest', 'Wandsworth',
#        'Westminster', 'Unnamed: 34', 'Inner London', 'Outer London',
#        'Unnamed: 37', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'Unnamed: 47', 'England'],
#       dtype='object')

# %%
# Reseting the index
properties_t.reset_index(inplace=True)
properties.index
# Out:
# RangeIndex(start=0, stop=306, step=1)

# %%
properties_t.head(2)
# Out:
#             index          0                    1                    2  \
# 0      Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1  City of London  E09000001                91449              82202.8
#
#                      3                    4                    5  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
#
#                      6                    7                    8  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
#
#                    296                  297                  298  \
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1               813770               810455               826227
#
#                    299                  300                  301  \
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# ...

# %%
# Assigning the values of the first row to the column headings
properties_t.columns = properties_t.iloc[0]
properties_t.head(2)
# Out:
# 0      Unnamed: 0        NaN  1995-01-01 00:00:00  1995-02-01 00:00:00  \
# 0      Unnamed: 0        NaT  1995-01-01 00:00:00  1995-02-01 00:00:00
# 1  City of London  E09000001                91449              82202.8
#
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00  \
# 0  1995-03-01 00:00:00  1995-04-01 00:00:00  1995-05-01 00:00:00
# 1              79120.7              77101.2              84409.1
#
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...  \
# 0  1995-06-01 00:00:00  1995-07-01 00:00:00  1995-08-01 00:00:00  ...
# 1              94900.5               110128               112329  ...
#
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00  \
# 0  2019-08-01 00:00:00  2019-09-01 00:00:00  2019-10-01 00:00:00
# 1               813770               810455               826227
#
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00  \
# 0  2019-11-01 00:00:00  2019-12-01 00:00:00  2020-01-01 00:00:00
# ...

# %%
# Droping the first row labeled by the index[0], which is replicated as a result of the previous step
properties_t.drop(properties_t.index[0], inplace=True)

# %%
properties_t.head(2)
# Out:
# 0          Unnamed: 0        NaN 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
#
# 0 2019-08-01 00:00:00 2019-09-01 00:00:00 2019-10-01 00:00:00  \
# 1              813770              810455              826227
# 2              299421              304778              304579
#
# 0 2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 1              776894              737275              747611
# ...

# %% [markdown]
# **2.3. Cleaning the data (part 2)**
#
# You might we have to **rename** a couple columns. How do you do this? The clue's pretty bold...

# %%
type(properties_t.columns[1])
# Out:
# pandas._libs.tslibs.nattype.NaTType

# %%
# Renaming some columns 
properties_t.rename(columns= {'Unnamed: 0' : 'London_Borough', properties_t.columns[1] : 'ID'}, inplace=True)
properties_t.head(2)
# Out:
# 0      London_Borough         ID 1995-01-01 00:00:00 1995-02-01 00:00:00  \
# 1      City of London  E09000001               91449             82202.8
# 2  Barking & Dagenham  E09000002             50460.2             51085.8
#
# 0 1995-03-01 00:00:00 1995-04-01 00:00:00 1995-05-01 00:00:00  \
# 1             79120.7             77101.2             84409.1
# 2               51269             53133.5             53042.2
#
# 0 1995-06-01 00:00:00 1995-07-01 00:00:00 1995-08-01 00:00:00  ...  \
# 1             94900.5              110128              112329  ...
# 2             53700.3             52113.1             52232.2  ...
#
# 0 2019-08-01 00:00:00 2019-09-01 00:00:00 2019-10-01 00:00:00  \
# 1              813770              810455              826227
# 2              299421              304778              304579
#
# 0 2019-11-01 00:00:00 2019-12-01 00:00:00 2020-01-01 00:00:00  \
# 1              776894              737275              747611
# ...

# %%
len(properties_t)
# Out:
# 48

# %%
# Checking the count of London boroughs based on the unique IDs
boroughs_count = len(properties_t['ID'].unique())
print(f'The number of Boroughs in the data set is: {boroughs_count}, where it should be 32 Boroughs')
# Out:
# The number of Boroughs in the data set is: 46, where it should be 32 Boroughs

# %% [markdown]
# **There is an issue. We need to focus only on the 32 London boroughs, will back to this issue later!**

# %% [markdown]
# **2.4.Transforming the data**
#
# Remember what Wes McKinney said about tidy data?
#
# You might need to **melt** your DataFrame here.

# %%
# Transforming the DataFrame from wide format to long format using pd.melt()
properties_clean = pd.melt(properties_t, id_vars= ['London_Borough', 'ID'])
properties_clean.head()
# Out:
#        London_Borough         ID          0    value
# 0      City of London  E09000001 1995-01-01    91449
# 1  Barking & Dagenham  E09000002 1995-01-01  50460.2
# 2              Barnet  E09000003 1995-01-01  93284.5
# 3              Bexley  E09000004 1995-01-01  64958.1
# 4               Brent  E09000005 1995-01-01  71306.6

# %%
properties_clean.tail()
# Out:
#       London_Borough         ID          0   value
# 14635         LONDON  E12000007 2020-05-01  479018
# 14636     SOUTH EAST  E12000008 2020-05-01  324659
# 14637     SOUTH WEST  E12000009 2020-05-01  261006
# 14638    Unnamed: 47        NaN 2020-05-01     NaN
# 14639        England  E92000001 2020-05-01  251973

# %%
len(properties_clean)
# Out:
# 14640

# %% [markdown]
# Remember to make sure your column data types are all correct. Average prices, for example, should be floating point numbers...

# %%
properties_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14640 entries, 0 to 14639
# Data columns (total 4 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   London_Borough  14640 non-null  object
#  1   ID              13725 non-null  object
#  2   0               14640 non-null  datetime64[ns]
#  3   value           13725 non-null  object
# dtypes: datetime64[ns](1), object(3)
# memory usage: 457.6+ KB

# %% [markdown]
# ##### 2.4.1- Change the value column to an appropriate numeric format

# %%
# Changing the value column to an appropriate numeric formt using pd.to_numeric()
properties_clean['value'] = pd.to_numeric(properties_clean['value'])

# %%
# Checking the updated data types
properties_clean.dtypes
# Out:
# London_Borough            object
# ID                        object
# 0                 datetime64[ns]
# value                    float64
# dtype: object

# %% [markdown]
# ##### 2.4.2- Rename some columns

# %%
properties_clean = properties_clean.rename(columns={0: 'Month', 'value': 'Average Price'})

# %%
properties_clean.columns
# Out:
# Index(['London_Borough', 'ID', 'Month', 'Average Price'], dtype='object')

# %% [markdown]
# **2.5. Cleaning the data (part 3)**
#
# Do we have an equal number of observations in the ID, Average Price, Month, and London Borough columns? Remember that there are only 32 London Boroughs. How many entries do you have in that column?
#
# Check out the contents of the London Borough column, and if you find null values, get rid of them however you see fit.

# %%
# Checking columns with null values
properties_clean.isnull().sum()
# Out:
# London_Borough      0
# ID                915
# Month               0
# Average Price     915
# dtype: int64

# %%
# Droping rows with null values
properties_clean = properties_clean.dropna()

# %%
print("The number of Boroughs should be 32 and we got", len(properties_clean.ID.unique()),)
# Out:
# The number of Boroughs should be 32 and we got 45

# %% [markdown]
# **Droping the null values did solve the problem, there is still need to filter the dataframe and keep only the 32 London boroughs.**

# %%
# Checking the unique boroughs names in the DataFrame
properties_clean.London_Borough.unique()
# Out:
# array(['City of London', 'Barking & Dagenham', 'Barnet', 'Bexley',
#        'Brent', 'Bromley', 'Camden', 'Croydon', 'Ealing', 'Enfield',
#        'Greenwich', 'Hackney', 'Hammersmith & Fulham', 'Haringey',
#        'Harrow', 'Havering', 'Hillingdon', 'Hounslow', 'Islington',
#        'Kensington & Chelsea', 'Kingston upon Thames', 'Lambeth',
#        'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster', 'Inner London',
#        'Outer London', 'NORTH EAST', 'NORTH WEST', 'YORKS & THE HUMBER',
#        'EAST MIDLANDS', 'WEST MIDLANDS', 'EAST OF ENGLAND', 'LONDON',
#        'SOUTH EAST', 'SOUTH WEST', 'England'], dtype=object)

# %% [markdown]
# **There are names that do not belong to the 32 London Boroughs. To solve this problem, we use data from wikipedia as an external data source to filter unwanted names.**

# %% [markdown]
# ##### **2.5.1 Using Wikipedia as an external source to detrmine the aproperiate Boroughs' names and more info**

# %%
# Reading tabels into a list of DataFrames from html link
link = 'https://en.wikipedia.org/wiki/List_of_London_boroughs'
tables = pd.read_html(link)

# %%
# The fisrt DataFrame in the list is of our interest. 
tables[0].head()
# Out:
#                          Borough Inner Status  \
# 0  Barking and Dagenham [note 1]   NaN    NaN
# 1                         Barnet   NaN    NaN
# 2                         Bexley   NaN    NaN
# 3                          Brent   NaN    NaN
# 4                        Bromley   NaN    NaN
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
#
#                                 Headquarters  Area (sq mi)  \
# 0                   Town Hall, 1 Town Square         13.93
# 1  Barnet House, 2 Bristol Avenue, Colindale         33.49
# 2            Civic Offices, 2 Watling Street         23.38
# ...

# %%
London_Borough_wiki =  tables[0]
print(f'The datat type is: {type(London_Borough_wiki)} and it has {len(London_Borough_wiki)} data entries.')
# Out:
# The datat type is: <class 'pandas.core.frame.DataFrame'> and it has 32 data entries.

# %% [markdown]
# * This DataFrame contains the exact number of the 32 London boroughs. We can use it as a reference to filter unwanted names from the original dataset instead of doing manual work. **However**, we need to deal with the scraping issues of the names in this dataframe to unify the names with the original data set. Names like "Barking and Dagenham [note 1]" needs to be cleaned. The Borough column needs to be inspected.
# * There is also an issue of the "Inner" column which should inform weather the borough is inner or outer.We can fix this issue by importing another tale from another wikipedia link.

# %% [markdown]
# **First**, we fix the imported borough names from wikipedia based on the original data set. Since the original data set has 45 unique borough names, all the imported 32 names should be included in orginal dataset.

# %%
# Save the unique unfiltered boroughs from the original dataframe in np.array
unique_unfiltered_boroughs = properties_clean['London_Borough'].unique()
type(unique_unfiltered_boroughs)
# Out:
# numpy.ndarray

# %%
# Filtering the unmatched spelling names in the imported data using the .query() function in one step. We could use the .isin() method but
         # using.query() is more consice and faster with big data size
# Note: the double bracket [['Borough']] is used to have a dataframe output instead of series for better presentation in the notebook

London_Borough_wiki.query("Borough not in @unique_unfiltered_boroughs")[['Borough']]
# Out:
#                             Borough
# 0     Barking and Dagenham [note 1]
# 9                Greenwich [note 2]
# 11  Hammersmith and Fulham [note 4]
# 18           Kensington and Chelsea

# %% [markdown]
# **There are four names need to be fixed.**

# %%
# Extracting these names from the original data to spot the differences. For loop used instead of direct print to have each name in separate line.

for i in unique_unfiltered_boroughs[[1, 10, 12, 19]]:
    print(i)
# Out:
# Barking & Dagenham
# Greenwich
# Hammersmith & Fulham
# Kensington & Chelsea

# %% [markdown]
# We can see that **"and"** needs to be changes to **'&'**. Also **[note 1]** should be removed. We use regular expression to accomplish this task.

# %%
# using regex with the identified pattern to eliminate the discrepancy in names found in the imported data from wikipedia.

London_Borough_wiki['Borough'] = London_Borough_wiki['Borough'].replace(regex=[r'\sand\s', r'\s\[.+\]'], value=[' & ', ''])

# %%
# Recheck again to make sure there is no discrepancy in the names using .query()
print(London_Borough_wiki.query("Borough not in @unique_unfiltered_boroughs")[['Borough']])

# Or we can check by counting the number of unmatched names by negating .isin() using "~"
print((~London_Borough_wiki['Borough'].isin(properties_clean['London_Borough'])).sum())
# Out:
# Empty DataFrame
# Columns: [Borough]
# Index: []
# 0

# %% [markdown]
# Both methods showed that the boroughs' names in the wikipedia dataset match the ones in the original data set. Now we can use wikipedia data to filter unwanted names from the original data and keep the 32 boroughs of interest.
# **However**, before we do this process, other columns in the wikipedia dataset dataset needs to be cleaned. In particular, the 'Inner' column that informs which borough is inner or outer. This column was not parsed properly because its representation was not text.
#
# **We will use another wikipedia link to determine which borough is inner or outer**

# %%
# Readng data from another wikipedia link into list of pandas dataframe
url_inner_boroughs = 'https://en.wikipedia.org/wiki/London_boroughs'
inner_outer_boroughs_wiki = pd.read_html(url_inner_boroughs)
inner_outer_boroughs_wiki[2].head()
# Out:
#          London borough Designation      Former areas         Former areas.1  \
# 0                Camden       Inner   Hampstead (11a)       St Pancras (11b)
# 1             Greenwich       Inner   Greenwich (22a)  Woolwich (part) (22b)
# 2               Hackney       Inner      Hackney (9a)        Shoreditch (9b)
# 3  Hammersmith[notes 2]       Inner  Hammersmith (4a)            Fulham (4b)
# 4             Islington       Inner   Islington (10a)         Finsbury (10b)
#
#          Former areas.2 Former areas.3 Former areas.4
# 0         Holborn (11c)            NaN            NaN
# 1                   NaN            NaN            NaN
# 2  Stoke Newington (9c)            NaN            NaN
# 3                   NaN            NaN            NaN
# 4                   NaN            NaN            NaN

# %%
# Extracting particular columns from the table of interest, namely 'London borough' and 'Designation', the later labels inner and outer boroughs
inner_outer_boroughs_wiki= inner_outer_boroughs_wiki[2].iloc[:, :2]
inner_outer_boroughs_wiki.sort_values('London borough').head(7)
# Out:
#       London borough Designation
# 12  Barking[notes 3]       Outer
# 13            Barnet       Outer
# 14            Bexley       Outer
# 15             Brent       Outer
# 16           Bromley       Outer
# 0             Camden       Inner
# 17           Croydon       Outer

# %% [markdown]
# There is an issue with the boroughs' names here too. We will follow a simlar approach to the previous one to have a consistent bourough naming according to the original data as the following:
# 1. Locate unmatching names.
# 2. Determine the unwanted text pattern.
# 3. Replce the unwanted pattern with the correct one.

# %% [markdown]
# Lets first rename the 'London borough' column to be 'Borough'

# %%
inner_outer_boroughs_wiki.rename(columns={'London borough' : 'Borough'}, inplace=True)

# %% [markdown]
# **Lets demonstrate using use the .isin() instead of .query() to filter unmatched names between the fixed wikipedia dataset and the other wikipedia one that has the 'Inner' column**

# %% [markdown]
# First: find unmatched names in the inner_outer_boroughs_wiki dataframe

# %%
idx = inner_outer_boroughs_wiki['Borough'].isin(London_Borough_wiki['Borough'])

# %%
inner_outer_boroughs_wiki[~idx]
# Out:
#                    Borough Designation
# 3     Hammersmith[notes 2]       Inner
# 5   Kensington and Chelsea       Inner
# 12        Barking[notes 3]       Outer

# %% [markdown]
# Second: find the unmatched names in the London_Borough_wiki dataframe with the fixed boroughs' names

# %%
idx1 = London_Borough_wiki['Borough'].isin(inner_outer_boroughs_wiki['Borough'])
London_Borough_wiki[~idx1][['Borough']]
# Out:
#                  Borough
# 0     Barking & Dagenham
# 11  Hammersmith & Fulham
# 18  Kensington & Chelsea

# %% [markdown]
# There are three names need to be fixed. From observing the outputs we can detrmine the pattern. The following code does the job.

# %%
inner_outer_boroughs_wiki['Borough'] = inner_outer_boroughs_wiki['Borough'].replace(regex=[r'\sand', r'\[.+\]'], value=[' &', ''])
inner_outer_boroughs_wiki['Borough'] = inner_outer_boroughs_wiki['Borough']\
                                        .replace(['Barking', 'Hammersmith'],['Barking & Dagenham', 'Hammersmith & Fulham'])

# %%
# Making sure there is no unmatching names any more
idx = inner_outer_boroughs_wiki['Borough'].isin(London_Borough_wiki['Borough'])
inner_outer_boroughs_wiki[~idx]
# Out:
# Empty DataFrame
# Columns: [Borough, Designation]
# Index: []

# %% [markdown]
# Now we can merge the two wikipedia datafarems to add the Designation column to the London_Borough_wiki dataframe, before that, we drop the 'Inner' column from it.

# %%
# Droping the 'Inner' column
London_Borough_wiki = London_Borough_wiki.drop('Inner', 1)

# %%
# Merging the two dataframes. The default is inner join
London_Borough_wiki = London_Borough_wiki.merge(inner_outer_boroughs_wiki, on='Borough', how='inner')
inner_outer_boroughs_wiki[['Borough', 'Designation']].head()
# Out:
#                 Borough Designation
# 0                Camden       Inner
# 1             Greenwich       Inner
# 2               Hackney       Inner
# 3  Hammersmith & Fulham       Inner
# 4             Islington       Inner

# %%
London_Borough_wiki.head()
# Out:
#               Borough Status                              Local authority  \
# 0  Barking & Dagenham    NaN  Barking and Dagenham London Borough Council
# 1              Barnet    NaN                Barnet London Borough Council
# 2              Bexley    NaN                Bexley London Borough Council
# 3               Brent    NaN                 Brent London Borough Council
# 4             Bromley    NaN               Bromley London Borough Council
#
#   Political control                               Headquarters  Area (sq mi)  \
# 0            Labour                   Town Hall, 1 Town Square         13.93
# 1      Conservative  Barnet House, 2 Bristol Avenue, Colindale         33.49
# 2      Conservative            Civic Offices, 2 Watling Street         23.38
# 3            Labour          Brent Civic Centre, Engineers Way         16.70
# 4      Conservative              Civic Centre, Stockwell Close         57.97
#
# ...

# %% [markdown]
# Let's inspect the status column

# %%
London_Borough_wiki['Status'].unique()
# Out:
# array([nan, 'Royal', 'City'], dtype=object)

# %% [markdown]
# The status column has null values for the boroughs that are not Royal nor city. We will fill the null value by "Not_Royal_Nor_City"

# %%
London_Borough_wiki['Status'] = London_Borough_wiki['Status'].fillna('Not_Royal_Nor_City')

# %%
London_Borough_wiki.head()
# Out:
#               Borough              Status  \
# 0  Barking & Dagenham  Not_Royal_Nor_City
# 1              Barnet  Not_Royal_Nor_City
# 2              Bexley  Not_Royal_Nor_City
# 3               Brent  Not_Royal_Nor_City
# 4             Bromley  Not_Royal_Nor_City
#
#                                Local authority Political control  \
# 0  Barking and Dagenham London Borough Council            Labour
# 1                Barnet London Borough Council      Conservative
# 2                Bexley London Borough Council      Conservative
# 3                 Brent London Borough Council            Labour
# 4               Bromley London Borough Council      Conservative
#
#                                 Headquarters  Area (sq mi)  \
# 0                   Town Hall, 1 Town Square         13.93
# 1  Barnet House, 2 Bristol Avenue, Colindale         33.49
# 2            Civic Offices, 2 Watling Street         23.38
# 3          Brent Civic Centre, Engineers Way         16.70
# ...

# %% [markdown]
# **With that, the London_Borough_wiki is ready for further analysis.**
#
# **Lets filter unwanted names from the original cleaned dataset 'properties_clean', using the 32  boroughs names from wikipedia**

# %%
# Filtering unmatching borough names form the original cleaned using the data from wikipedia 
properties_final = properties_clean.query('London_Borough in @London_Borough_wiki.Borough')

# %%
# Checking weather we have only 32 boroughs in the originl data
len(properties_final['London_Borough'].unique())
# Out:
# 32

# %% [markdown]
# #### **<center>Now the original dataset is clean and ready for analysis<center>**

# %%
properties_final.head()
# Out:
#        London_Borough         ID      Month  Average Price
# 1  Barking & Dagenham  E09000002 1995-01-01    50460.22660
# 2              Barnet  E09000003 1995-01-01    93284.51832
# 3              Bexley  E09000004 1995-01-01    64958.09036
# 4               Brent  E09000005 1995-01-01    71306.56698
# 5             Bromley  E09000006 1995-01-01    81671.47692

# %% [markdown]
# ### **2.6. Visualizing the data**
#
# To visualize the data, why not subset on a particular London Borough? Maybe do a line plot of Month against Average Price?

# %% [markdown]
# To limit the number of data points you have, you might want to extract the year from every month value your *Month* column.
#
# To this end, you *could* apply a ***lambda function***. Your logic could work as follows:
# 1. look through the `Month` column
# 2. extract the year from each individual value in that column
# 3. store that corresponding year as separate column.
#
# Whether you go ahead with this is up to you. Just so long as you answer our initial brief: which boroughs of London have seen the greatest house price increase, on average, over the past two decades?

# %% [markdown]
# **First, we look to the average price distribution in the Boroughs of London**

# %%
sns.set_style("whitegrid")

# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(16.0, 8.0))
fig.suptitle('Average Price Distribution of London Boroughs (1995 - 2020)', fontsize=15 )
palette = sns.color_palette("Paired", 2)

ax = sns.distplot(properties_final['Average Price'], bins=50, rug=True)
ax.set_xlabel("Average Price",fontsize=15)

xlabels = ['{:,.0f}'.format(x) + 'K' for x in ax.get_xticks()/1000]
ax.set_xticklabels(xlabels)
ylabels = ['' for y in ax.get_yticks()]
ax.set_yticklabels(ylabels)

ax.tick_params(labelsize=12)
sns.despine(bottom=True)
plt.tight_layout(h_pad=2)

# %% [markdown]
# The distribution plot shows that most of the housing prices of London Boroughs from 1995 to 2020 are between 100k and 600k. However, there are some outliers with higher prices up to 1,400,000.

# %% [markdown]
# **Let's findout the maximum average price for london boroughs**

# %%
max_avg_price = properties_final.groupby('London_Borough')['Average Price'].max().sort_values(ascending=False)

# %%
max_avg_price.apply(lambda p: round(p, 2)).head()
# Out:
# London_Borough
# Kensington & Chelsea    1463377.92
# Westminster             1117407.52
# Camden                   890288.41
# Hammersmith & Fulham     781175.04
# Islington                706263.09
# Name: Average Price, dtype: float64

# %% [markdown]
# **Extracting the rows with max average price from the data set**

# %%
idx = properties_final.groupby('London_Borough')['Average Price'].transform(max) == properties_final['Average Price']

# %%
propertie_max = properties_final[idx].sort_values('Average Price', ascending=False)

# %%
propertie_max.head()
# Out:
#              London_Borough         ID      Month  Average Price
# 13267  Kensington & Chelsea  E09000020 2018-01-01   1.463378e+06
# 13328           Westminster  E09000033 2018-02-01   1.117408e+06
# 14118                Camden  E09000007 2019-07-01   8.902884e+05
# 13020  Hammersmith & Fulham  E09000013 2017-08-01   7.811750e+05
# 14562             Islington  E09000019 2020-04-01   7.062631e+05

# %%
London_Borough_wiki.rename(columns= {'Borough':'London_Borough'}, inplace=True)

# %%
propertie_max = propertie_max.merge(London_Borough_wiki, on='London_Borough')

# %%
propertie_max.head()
# Out:
#          London_Borough         ID      Month  Average Price  \
# 0  Kensington & Chelsea  E09000020 2018-01-01   1.463378e+06
# 1           Westminster  E09000033 2018-02-01   1.117408e+06
# 2                Camden  E09000007 2019-07-01   8.902884e+05
# 3  Hammersmith & Fulham  E09000013 2017-08-01   7.811750e+05
# 4             Islington  E09000019 2020-04-01   7.062631e+05
#
#                Status                                Local authority  \
# 0               Royal  Kensington and Chelsea London Borough Council
# 1                City                       Westminster City Council
# 2  Not_Royal_Nor_City                  Camden London Borough Council
# 3  Not_Royal_Nor_City  Hammersmith and Fulham London Borough Council
# 4  Not_Royal_Nor_City               Islington London Borough Council
#
#   Political control                               Headquarters  Area (sq mi)  \
# 0      Conservative              The Town Hall, Hornton Street          4.68
# ...

# %%
propertie_max.tail()
# Out:
#         London_Borough         ID      Month  Average Price  \
# 27             Croydon  E09000008 2020-04-01   386737.93080
# 28              Newham  E09000025 2020-03-01   379836.67530
# 29            Havering  E09000016 2020-04-01   378746.97680
# 30              Bexley  E09000004 2018-08-01   347531.06171
# 31  Barking & Dagenham  E09000002 2019-11-01   306390.26430
#
#                 Status                              Local authority  \
# 27  Not_Royal_Nor_City               Croydon London Borough Council
# 28  Not_Royal_Nor_City                Newham London Borough Council
# 29  Not_Royal_Nor_City              Havering London Borough Council
# 30  Not_Royal_Nor_City                Bexley London Borough Council
# 31  Not_Royal_Nor_City  Barking and Dagenham London Borough Council
#
#              Political control                         Headquarters  \
# 27                      Labour  Bernard Weatherill House, Mint Walk
# ...

# %%
sns.set_style("whitegrid")


# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(22.0, 13.0))
fig.suptitle('Max Average Price of London Boroughs (1995 - 2020)', fontsize=25 )
palette = sns.color_palette("Paired", 2)

sns.barplot(x='London_Borough', y='Average Price', data= propertie_max, hue='Designation', palette=palette, ax=ax)


ax.set_xlabel("London Boroughs",fontsize=25)
ax.set_ylabel("Average Price",fontsize=25)
ax.set_yticklabels(ax.get_yticks(), size=13)
plt.setp(ax.get_legend().get_texts(), fontsize=20)
sns.despine(left=True, bottom=True)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, size=15)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects.patches:
        height = rect.get_height()
        ax.annotate('{:,.0f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 20),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='center', size=16, color='r', rotation=40)


autolabel(ax)


fig.tight_layout()

# %% [markdown]
# **The takeaway** is that the Inner Boroughs seems to have a higher prices than the Outer ones.

# %% [markdown]
# #### Political prespective

# %%
sns.set_style("whitegrid")


# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(22.0, 13.0))
fig.suptitle('Max Average Price of London Boroughs (1995 - 2020) based on the Political Control as of 2013', fontsize=25 )


sns.barplot(x='London_Borough', y='Average Price', data= propertie_max, hue='Political control', palette="tab10", ax=ax)


ax.set_xlabel("London Boroughs",fontsize=25)
ax.set_ylabel("Average Price",fontsize=25)
ax.set_yticklabels(ax.get_yticks(), size=13)
plt.setp(ax.get_legend().get_texts(), fontsize=20)
sns.despine(left=True, bottom=True)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, size=15)
def autolabel(rects):
    """Attach a text label above each bar in *rects*, displaying its height."""
    for rect in rects.patches:
        height = rect.get_height()
        ax.annotate('{:,.0f}'.format(height),
                    xy=(rect.get_x() + rect.get_width() / 2, height),
                    xytext=(0, 20),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='center', size=16, color='r', rotation=40)


autolabel(ax)
ax.annotate('Source: Wikipedia data showsthe political control as of 2013',
           xy=(0.9, 0.9), xycoords='figure fraction',
           horizontalalignment='right', verticalalignment='top',
           fontsize=14, color='#555555')

fig.tight_layout()

# %% [markdown]
# **Takeaway:** The merged Wikipedia shows that as of 2013 the conservative party is in control of two most expensive boroughs. On the other hand, in 2013, the Labour party is in control of most of the boroughs, approximately 21 boroughs out of 32.

# %% [markdown]
# **Viewing the pricing trend over years**

# %%
fp = properties_final.copy()

# %%
# Adding the year column to the dataframe
fp['year'] = fp.Month.dt.year

# %%
# Setting Multi-level index to the dataframe
fp = fp.set_index(['London_Borough', 'year']).sort_index()
fp.head()
# Out:
#                                 ID      Month  Average Price
# London_Borough     year
# Barking & Dagenham 1995  E09000002 1995-01-01    50460.22660
#                    1995  E09000002 1995-02-01    51085.77983
#                    1995  E09000002 1995-03-01    51268.96956
#                    1995  E09000002 1995-04-01    53133.50526
#                    1995  E09000002 1995-05-01    53042.24852

# %%
# setting an index of the boroughs sorted according to maximum price in a descending order
idx = propertie_max['London_Borough'].unique()

# %%
# Taking advantage of seaborn FacitGrid to generte linplots of the prices over years for each borough
sns.set_style("ticks")
sns.set(font_scale=2)
# Initialize a grid of plots with an Axes for each borough
grid = sns.FacetGrid(properties_final, col='London_Borough', hue="London_Borough", palette="tab20c",
                     col_wrap=4, height=4, aspect=2)

def grid_plot(df, ax, borough):
    '''This function generates a line plot for each borough by taking filtered borough dataframe (df) and
    one of the FacitGrid axes (ax) as parameters'''
    # Generating line plot
    sns.lineplot(x= df.index, y='Average Price', data=df, ax=ax, palette="tab20c").set(title=borough)
    
# loping through the ordered boroughs and facitgrid axes to generate lineplot for each borough prcises on a particular axes 
for borough, ax in zip(idx, grid.axes):
    df = fp.loc[borough]
    grid_plot(df, ax, borough)

# %% [markdown]
# **Zooming on boroughs with minimum and maximum average price**

# %%
min_max = properties_final.query('London_Borough in ["Barking & Dagenham", "Kensington & Chelsea"]')

# %%
f, ax = plt.subplots(figsize=(20, 10))

sns.set_style("whitegrid")

sns.lineplot(x= min_max.Month.dt.year, y='Average Price', data=min_max, color='r',  hue='London_Borough', ax=ax)
ax.axes.set_title("Boroughs with Max and Min Average Price Over Years",fontsize=20)
ax.set_xlabel("Year",fontsize=20)
ax.set_ylabel("Average Parice",fontsize=20)

xlabels = [int(x) for x in ax.get_xticks()]
ax.set_xticklabels(xlabels)
ylabels = ['{:,.2f}'.format(y) + 'K' for y in ax.get_yticks()/1000]
ax.set_yticklabels(ylabels)

ax.tick_params(labelsize=15)
plt.setp(ax.get_legend().get_texts(), fontsize='15')
sns.despine(left=True, bottom=True)
plt.tight_layout(h_pad=2)

# %% [markdown]
# Ploting all of the boroughs prices together for comparing the trend in the boroughs prices

# %%
f, ax = plt.subplots(figsize=(24, 15))

sns.set_style("whitegrid")

sns.lineplot(x= properties_final.Month.dt.year, y='Average Price', data=properties_final, color='r',  hue='London_Borough', ax=ax)
ax.axes.set_title("Boroughs Average Price Over Years",fontsize=20)
ax.set_xlabel("Year",fontsize=20)
ax.set_ylabel("Average Parice",fontsize=20)

xlabels = [int(x) for x in ax.get_xticks()]
ax.set_xticklabels(xlabels)
ylabels = ['{:,.2f}'.format(y) + 'K' for y in ax.get_yticks()/1000]
ax.set_yticklabels(ylabels)

ax.tick_params(labelsize=15)
ax.legend(frameon=True, loc='upper left', ncol=4)

plt.setp(ax.get_legend().get_texts(), fontsize='14')
sns.despine(left=True, bottom=True)
plt.tight_layout(h_pad=2)

# %% [markdown]
# **The takeaway** is that there is an increasing trend in general in the boroughs housing prices. **However**, there is a **remarkable drop** in all of the prices during the years 2007 and 2008, probably from the financial crises then. There is also a more recent, **sharp drop**, mostly in the expensive areas during the year 2019.

# %% [markdown]
# ### Brief Geo Data Visualization

# %%
import geopandas as gpd
import mapclassify as mc
import adjustText as aT

# %% [markdown]
# **Source: The Geo Data wasdownlaoded from "EUROPEAN DATA PORTAL: Statistical GIS Boundary Files for London" under this link:**
# https://www.europeandataportal.eu/data/datasets/statistical-gis-boundary-files-for-london?locale=en

# %%
fp = "/home/ahmed/Desktop/Springboard/Resources/statistical-gis-boundaries-london/ESRI/London_Borough_Excluding_MHW.shp"

map_df = gpd.read_file(fp)

# %%
fp = "/home/ahmed/Desktop/Springboard/Resources/lp-consultation-oct-2009-inner-outer-london-shp/lp-consultation-oct-2009-inner-outer-london.shp"

inner_outer_map = gpd.read_file(fp)
inner_outer_map = inner_outer_map.to_crs('epsg:3395')

# %%
map_df.head()
# Out:
#                    NAME   GSS_CODE   HECTARES  NONLD_AREA ONS_INNER SUB_2009  \
# 0  Kingston upon Thames  E09000021   3726.117       0.000         F     None
# 1               Croydon  E09000008   8649.441       0.000         F     None
# 2               Bromley  E09000006  15013.487       0.000         F     None
# 3              Hounslow  E09000018   5658.541      60.755         F     None
# 4                Ealing  E09000009   5554.428       0.000         F     None
#
#   SUB_2006                                           geometry
# 0     None  POLYGON ((516401.600 160201.800, 516407.300 16...
# 1     None  POLYGON ((535009.200 159504.700, 535005.500 15...
# 2     None  POLYGON ((540373.600 157530.400, 540361.200 15...
# 3     None  POLYGON ((521975.800 178100.000, 521967.700 17...
# 4     None  POLYGON ((510253.500 182881.600, 510249.900 18...

# %%
# Making sure the GIS data contains all of the London boroughs information
idx1 = map_df['GSS_CODE'].isin(propertie_max['ID'])
boroughs_map = map_df.loc[idx1, ['GSS_CODE', 'HECTARES', 'geometry']]

# %%
# Changing the coordinate system
boroughs_map = boroughs_map.to_crs('epsg:3395')

# %%
# Merging the GeoPandas dataframe with the max average prices dataframe 
max_map =boroughs_map.merge(propertie_max, left_on='GSS_CODE', right_on='ID')
max_map = max_map.drop('GSS_CODE', axis=1)

# %%
max_map.head()
# Out:
#     HECTARES                                           geometry  \
# 0   3726.117  POLYGON ((-36811.020 6646318.080, -36801.601 6...
# 1   8649.441  POLYGON ((-7126.807 6644475.078, -7132.828 664...
# 2  15013.487  POLYGON ((1350.415 6641093.639, 1331.568 66411...
# 3   5658.541  POLYGON ((-27224.557 6674742.964, -27237.660 6...
# 4   5554.428  POLYGON ((-45845.001 6682839.117, -45850.623 6...
#
#          London_Borough         ID      Month  Average Price  \
# 0  Kingston upon Thames  E09000021 2018-06-01   511260.04650
# 1               Croydon  E09000008 2020-04-01   386737.93080
# 2               Bromley  E09000006 2018-09-01   449292.94154
# 3              Hounslow  E09000018 2020-05-01   416680.64160
# 4                Ealing  E09000009 2020-04-01   502107.07390
#
#                Status                              Local authority  \
# 0               Royal  Kingston upon Thames London Borough Council
# 1  Not_Royal_Nor_City               Croydon London Borough Council
# ...

# %% [markdown]
# #### Applying Fisker Jenks to classify the Max Average Prices in 5 Intervals

# %%
fj_max_map = mc.FisherJenks(max_map['Average Price'], k=5)

# %%
print(fj_max_map)
# Out:
# FisherJenks
#
#         Interval           Count
# --------------------------------
# [ 306390.26,  449292.94] |    14
# ( 449292.94,  633826.05] |    12
# ( 633826.05,  890288.41] |     4
# ( 890288.41, 1117407.52] |     1
# (1117407.52, 1463377.92] |     1

# %% [markdown]
# **Generating a Choropleth map that shows the maximum average prices of the boroughs**

# %%
sns.set_style("dark")

# set a variable that will call whatever column we want to visualise on the map
variable = 'Average Price'

# set the range for the choropleth
vmin, vmax = max_map['Average Price'].min(), max_map['Average Price'].max()

# create figure and axes for Matplotlib
fig, ax = plt.subplots(figsize=(18, 10))

# create map
max_map.plot(column=variable, cmap='Blues', linewidth=0.8, ax=ax, edgecolor='0.8', scheme='FisherJenks',  legend=True)

# Now we can customise and add annotations

# remove the axis
ax.axis('off')

# add a title
ax.set_title('London Boroughs Maximum Average Price', \
              fontdict={'fontsize': '16',
                        'fontweight' : '1'})

# create an annotation for the  data source
ax.annotate('Source: EUROPEAN DATA PORTAL: Statistical GIS Boundary Files for London',
           xy=(0.1, .08), xycoords='figure fraction',
           horizontalalignment='left', verticalalignment='top',
           fontsize=10, color='#555555')

# Create colorbar as a legend
sm = plt.cm.ScalarMappable(cmap='Blues', norm=plt.Normalize(vmin=vmin, vmax=vmax))
cbar = fig.colorbar(sm)
cbar.ax.tick_params(labelsize=12)

plt.setp(ax.get_legend().get_texts(), fontsize='13')

# The following code the adjustText library to put the boroughs' names nicely on the map
max_map["center"] = max_map["geometry"].centroid
map_points = max_map.copy()
map_points.set_geometry("center", inplace = True)

texts = []
for x, y, label in zip(map_points.geometry.x, map_points.geometry.y, map_points["London_Borough"]):
    texts.append(ax.text(x, y, label, fontsize = 10, color='red'))

aT.adjust_text(texts, force_points=0.3, force_text=0.8, expand_points=(1,1), expand_text=(1,1), 
               arrowprops=dict(arrowstyle="-", color='grey', lw=0.5))
plt.tight_layout(h_pad=2)
plt.show()

# %% [markdown]
# **Calculating maximum percent change in price month to month over years for each borough**

# %% [markdown]
# Here we calculate the pct_change for each borough seperately, by looping through each one, to avoid considering rows the next borough in the dataframe. pandas calculates the pct_change() method as the following equatasion:
# \begin{equation*}
# Percent Change = \frac{row[x] - row[x+1]}{\lvert row[x] \rvert}
# \end{equation*}
# Also, we used a sorted two level multi-index to avoid duplicates in in the boroughs column. This to avoid pandas errors like "cannot reindex from a duplicate axis".

# %%
# Assign multi-index to pandas dataframe
properties_final = properties_final.set_index(['London_Borough', 'Month']).sort_index()

# %%
properties_final.head()
# Out:
#                                       ID  Average Price
# London_Borough     Month
# Barking & Dagenham 1995-01-01  E09000002    50460.22660
#                    1995-02-01  E09000002    51085.77983
#                    1995-03-01  E09000002    51268.96956
#                    1995-04-01  E09000002    53133.50526
#                    1995-05-01  E09000002    53042.24852

# %%
# Extract a list of unique indexes (boroughs in this case)
idx_boroughs = properties_final.index.get_level_values('London_Borough').unique()
# Looping through the boroughs list to calculate the percent change for each one and assign it to a new column.
for idx in idx_boroughs:
    properties_final.loc[(idx, slice(None)), 'percent_change'] = properties_final\
                                                                .loc[(idx, slice(None)), 'Average Price'].pct_change()

# %%
properties_final.isnull().any()
# Out:
# ID                False
# Average Price     False
# percent_change     True
# dtype: bool

# %%
max_pct_change = properties_final.groupby(level=0)['percent_change'].max().sort_values(ascending=False)

# %%
max_pct_change.head()
# Out:
# London_Borough
# Brent                   0.103942
# Kensington & Chelsea    0.090912
# Southwark               0.086063
# Tower Hamlets           0.080630
# Lambeth                 0.077627
# Name: percent_change, dtype: float64

# %%
max_pct_change = pd.DataFrame(max_pct_change).reset_index()

# %%
properties_final.reset_index(inplace=True)

# %%
propertie_max_pct_change = max_pct_change.merge(properties_final, on=['London_Borough', 'percent_change'])

# %%
propertie_max_pct_change.count()
# Out:
# London_Borough    32
# percent_change    32
# Month             32
# ID                32
# Average Price     32
# dtype: int64

# %%
propertie_max_pct_change =propertie_max_pct_change.merge(London_Borough_wiki, on='London_Borough')

# %%
propertie_max_pct_change.head()
# Out:
#          London_Borough  percent_change      Month         ID  Average Price  \
# 0                 Brent        0.103942 2020-02-01  E09000005   467144.91460
# 1  Kensington & Chelsea        0.090912 2011-04-01  E09000020   959519.87750
# 2             Southwark        0.086063 1999-09-01  E09000028   119479.53170
# 3         Tower Hamlets        0.080630 1997-02-01  E09000030    80440.91184
# 4               Lambeth        0.077627 1997-07-01  E09000022    91999.42510
#
#                Status                                Local authority  \
# 0  Not_Royal_Nor_City                   Brent London Borough Council
# 1               Royal  Kensington and Chelsea London Borough Council
# 2  Not_Royal_Nor_City               Southwark London Borough Council
# 3  Not_Royal_Nor_City           Tower Hamlets London Borough Council
# 4  Not_Royal_Nor_City                 Lambeth London Borough Council
#
#   Political control                                 Headquarters  \
# ...

# %%
sns.set_style("whitegrid")


# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(22.0, 13.0))
fig.suptitle('Max Price Percentage Change from Month to Month of London Boroughs (1995 - 2020)', fontsize=25 )


sns.barplot(x='London_Borough', y='percent_change', data= propertie_max_pct_change, hue='Designation',palette='Blues_d', ax=ax)


ax.set_xlabel("London Boroughs",fontsize=20)
ax.set_ylabel("Percentage Change in Price Between Two Consecutive Months",fontsize=20)
ax.set_yticklabels(ax.get_yticks(), size=13)
plt.setp(ax.get_legend().get_texts(), fontsize=20)
sns.despine(left=True, bottom=True)

ax.set_xticklabels(ax.get_xticklabels(), rotation=90, size=18)

fig.tight_layout()

# %% [markdown]
# **3. Modeling**
#
# Consider creating a function that will calculate a ratio of house prices, comparing the price of a house in 2018 to the price in 1998.
#
# Consider calling this function create_price_ratio.
#
# You'd want this function to:
# 1. Take a filter of dfg, specifically where this filter constrains the London_Borough, as an argument. For example, one admissible argument should be: dfg[dfg['London_Borough']=='Camden'].
# 2. Get the Average Price for that Borough, for the years 1998 and 2018.
# 4. Calculate the ratio of the Average Price for 1998 divided by the Average Price for 2018.
# 5. Return that ratio.
#
# Once you've written this function, you ultimately want to use it to iterate through all the unique London_Boroughs and work out the ratio capturing the difference of house prices between 1998 and 2018.
#
# Bear in mind: you don't have to write a function like this if you don't want to. If you can solve the brief otherwise, then great!
#
# ***Hint***: This section should test the skills you acquired in:
# - Python Data Science Toolbox - Part One, all modules

# %%
properties_final.head()
# Out:
#        London_Borough      Month         ID  Average Price  percent_change
# 0  Barking & Dagenham 1995-01-01  E09000002    50460.22660             NaN
# 1  Barking & Dagenham 1995-02-01  E09000002    51085.77983        0.012397
# 2  Barking & Dagenham 1995-03-01  E09000002    51268.96956        0.003586
# 3  Barking & Dagenham 1995-04-01  E09000002    53133.50526        0.036368
# 4  Barking & Dagenham 1995-05-01  E09000002    53042.24852       -0.001717

# %%
properties_final.head()
# Out:
#        London_Borough      Month         ID  Average Price  percent_change
# 0  Barking & Dagenham 1995-01-01  E09000002    50460.22660             NaN
# 1  Barking & Dagenham 1995-02-01  E09000002    51085.77983        0.012397
# 2  Barking & Dagenham 1995-03-01  E09000002    51268.96956        0.003586
# 3  Barking & Dagenham 1995-04-01  E09000002    53133.50526        0.036368
# 4  Barking & Dagenham 1995-05-01  E09000002    53042.24852       -0.001717

# %%
properties_final['year'] = properties_final.Month.dt.year

# %%
price_year = properties_final.groupby(['London_Borough', 'year'])[['Average Price', 'percent_change']].mean()
price_year.head()
# Out:
#                          Average Price  percent_change
# London_Borough     year
# Barking & Dagenham 1995   51817.969390        0.001001
#                    1996   51718.192690        0.004713
#                    1997   55974.262309        0.006270
#                    1998   60285.821083        0.007568
#                    1999   65320.934441        0.006773

# %%
price_year.reset_index(level=1, inplace=True)
price_year.head()
# Out:
#                     year  Average Price  percent_change
# London_Borough
# Barking & Dagenham  1995   51817.969390        0.001001
# Barking & Dagenham  1996   51718.192690        0.004713
# Barking & Dagenham  1997   55974.262309        0.006270
# Barking & Dagenham  1998   60285.821083        0.007568
# Barking & Dagenham  1999   65320.934441        0.006773

# %%
price_year.index.unique()
# Out:
# Index(['Barking & Dagenham', 'Barnet', 'Bexley', 'Brent', 'Bromley', 'Camden',
#        'Croydon', 'Ealing', 'Enfield', 'Greenwich', 'Hackney',
#        'Hammersmith & Fulham', 'Haringey', 'Harrow', 'Havering', 'Hillingdon',
#        'Hounslow', 'Islington', 'Kensington & Chelsea', 'Kingston upon Thames',
#        'Lambeth', 'Lewisham', 'Merton', 'Newham', 'Redbridge',
#        'Richmond upon Thames', 'Southwark', 'Sutton', 'Tower Hamlets',
#        'Waltham Forest', 'Wandsworth', 'Westminster'],
#       dtype='object', name='London_Borough')

# %%
def create_price_ratio(sub_df):
    ''' This function calculates the price ration between 1998 and 2018 (year1998 / year 2018)'''
    return sub_df.loc[sub_df.year == 2018,'Average Price'].values / sub_df.loc[sub_df.year == 1998 , 'Average Price'].values

# %%
ratio_dict = {}

# %%
for borough in price_year.index.unique():
    #ratio_1998_2018.append([borough, create_price_ratio(price_year[borough])
    ratio_dict[borough] = create_price_ratio(price_year.loc[borough, :])

# %%
price_ratio_1998_2018 = pd.DataFrame(ratio_dict)

# %%
price_ratio_1998_2018 = pd.DataFrame(ratio_dict).transpose()

# %%
price_ratio_1998_2018.rename(columns=({0: 'ratio'}), inplace=True)
price_ratio_1998_2018.index.names = ['London_Borough']
price_ratio_1998_2018.sort_values('ratio' , inplace=True, ascending=False)

# %%
price_ratio_1998_2018.head()
# Out:
#                    ratio
# London_Borough
# Hackney         6.198286
# Waltham Forest  5.834756
# Southwark       5.516485
# Lewisham        5.449221
# Westminster     5.353565

# %%
format_dict = {'ratio':'{:.2f}'}
price_ratio_1998_2018.style.format(format_dict).highlight_min('ratio', color='pink').highlight_max('ratio', color='lightgreen')
# Out:
# <style  type="text/css" >
#     #T_d06ec21c_0153_11eb_9aaf_f57804ff9b5frow0_col0 {
#             : ;
#             background-color:  lightgreen;
#         }    #T_d06ec21c_0153_11eb_9aaf_f57804ff9b5frow31_col0 {
#             background-color:  pink;
#             : ;
#         }</style><table id="T_d06ec21c_0153_11eb_9aaf_f57804ff9b5f" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >ratio</th>    </tr>    <tr>        <th class="index_name level0" >London_Borough</th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d06ec21c_0153_11eb_9aaf_f57804ff9b5flevel0_row0" class="row_heading level0 row0" >Hackney</th>
#                         <td id="T_d06ec21c_0153_11eb_9aaf_f57804ff9b5frow0_col0" class="data row0 col0" >6.20</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# **Since we claculated the ratio as (year 2018 price / year 1998 price), higher ratio indicates the greatest increase in housing prices, on average from 1998 to 2018. Thus, Hackney with 6.20 has the greatest increase in housing prices**

# %%
sns.set_style("whitegrid")


# Initialize the matplotlib figure
fig, ax = plt.subplots(figsize=(15.0, 10.0))
fig.suptitle('Price Ratio Change of London Boroughs (1995 - 2018)', fontsize=16 )

sns.barplot(x=price_ratio_1998_2018.index, y='ratio', data=price_ratio_1998_2018, ax=ax, palette=("Blues_d"))

ax.set_xlabel("London Boroughs",fontsize=18)
ax.set_xticklabels(ax.get_xticklabels(), rotation=90, size=18)

ax.set_ylabel("Change Ratio year1995 / year2018",fontsize=18)



ylabels = ['{:.2f}'.format(y) for y in ax.get_yticks()]
ax.set_yticklabels(ylabels,  size=13)

#plt.setp(ax.get_legend().get_texts(), fontsize=12)
sns.despine(left=True, bottom=True)

fig.tight_layout()

# %% [markdown]
# ### 4. Conclusion
#
# From the exploratory data analysis, one can conclude the following:
#
# 1. The average price of the London borough, **Hackney**, has increased **6.2** times in 2018 than it was in 1998.
# 2. The borough of **Kensington & Chelsea** reported the highest maximum average price with **£1,463,378** in 2018.
# 3. The borough of **Barking & Dagenham** reported the lowest maximum average housing price with **£306,390** in 2019 comparing to other boroughs.
# 4. The maximum average price of Kensington & Chelsea is approximately 5 times more than the max price in Barking & Dagenham.
# 5. There is an overall increasing trend, in general, in the housing prices of the boroughs. However, one can notice there was a  remarkable drop in all of the prices during 2007 and 2008, probably from the financial crises then. There is also a more recent, sharp drop, mostly in the expensive areas during the year 2019.
# 6. Based on analyzing Wikipedia data, as of 2013, the conservative party is in control of the two most expensive boroughs. On the other hand, in 2013, the Labour party is in control of most of the boroughs, approximately 21 boroughs out of 32. The conservative party controls 7 out of 32 boroughs. The Liberal Democrat party controls 3 out of 32 boroughs.
#
# This project has involved several techniques and used various tools to accomplish an Exploratory Data Analysis. The analysis involved using other data sources for adding more information about the topic of the study as well as to clean the given data. The cleaning included other data to have an exact 32 London Boroughs of interest along and filter many of not wanted names. Seaborn along with Matplotlib and Pandas is used for data visualization. GeoPandas with mapclassify libraries is also used to generate Geo-based visualization, namely the Choropleth map. These tools and techniques if leveraged optimally can help in solving complex data science problems.
#
# This analysis can be further extended by studying other dimensions like the population and its change for each borough and investigate the relationship between the population and the average price for each borough.
# Also, by considering other features related to the house prices of London boroughs, one can build a predictive model that predicts the change in the average prices. One interesting idea is to consider news-based sentiment analysis for predicting the house prices of London boroughs.
